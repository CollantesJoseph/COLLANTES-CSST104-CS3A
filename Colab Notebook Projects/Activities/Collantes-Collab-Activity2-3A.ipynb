# %%
pip install automata-lib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 1.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **1. Import library**![collab-activity2.png](data:image/png;base64,...)

# %%
from automata.fa.dfa import DFA

# %% [markdown]
# **2. Define DFA, states, transitions, start, final, input symbols**

# %%
dfa = DFA (
    states = {'q0', 'q1'},
    input_symbols = {'0', '1'},
    transitions = {
        'q0':{'0': 'q0', '1': 'q1'},
        'q1':{'0': 'q1', '0': 'q0', '1': 'q1', '1': 'q0'}
    },
    initial_state = 'q0',
    final_states = {'q0'}
)

# %% [markdown]
# **3. Define the functions**

# %%
def is_accepted(input_str):
  return dfa.accepts_input(input_str)

# %% [markdown]
# **4. Test the DFA**

# %%
test_strings = ['110', '101', '000', '111', '10101', '1011']

for test_str in test_strings:
  if is_accepted(test_str):
    print(f'String"{test_str}" is accepted.')
  else:
    print(f'String"{test_str}" is not accepted.')
# Out:
# String"110" is accepted.
# String"101" is not accepted.
# String"000" is accepted.
# String"111" is not accepted.
# String"10101" is not accepted.
# String"1011" is accepted.
